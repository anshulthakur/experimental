# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
#Import basic libraries
# %matplotlib inline

from __future__ import print_function
import httplib2
import os

import pandas as pd
import os.path
import traceback
import re
from datetime import datetime

from urllib.parse import parse_qs, urlparse

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

import unittest
from pprint import pprint

# %%
# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

#Other scopes
#https://www.googleapis.com/auth/drive
#https://www.googleapis.com/auth/drive.readonly
#https://www.googleapis.com/auth/drive.file
#https://www.googleapis.com/auth/spreadsheets

APPLICATION_NAME = 'Python Interface Exploration'

# %%
class Sheets:
    def __init__(self, creds, spreadsheet_id, cache_folder='cache', offline=False):
        if offline:
            print('Working in offline mode. Make sure that the cached files are present.')
        self.creds = creds
        self.spreadsheet_id = spreadsheet_id
        self.offline = offline
        self.service = build('sheets', 'v4', credentials=self.creds) if not offline else None
        self.cache_folder = cache_folder


    def open(self, sheet_names):
        try:
            # Create the cache folder if it doesn't exist
            if not os.path.exists(self.cache_folder):
                os.makedirs(self.cache_folder)
            
            # Dictionary to store DataFrames for each sheet
            df = None
            dataframes = []
            for sheet_name in sheet_names:
                s_df = None
                cache_file = os.path.join(self.cache_folder, f"{sheet_name}.csv")

                # Check if a cached CSV file exists
                if os.path.exists(cache_file):
                    s_df = pd.read_csv(cache_file, index_col="Date")
                    s_df.index = pd.to_datetime(s_df.index)
                    #print(f'Load {cache_file} from cache')
                else:
                    # Fetch data from Google Sheets
                    s_df = self.fetch_data(sheet_name)

                    # Save the fetched data to a CSV file for caching
                    s_df.to_csv(cache_file)

                dataframes.append(s_df)

            df = pd.concat(dataframes, join='outer', sort=True)
            df.sort_index(inplace=True)

            # Now, df contains the combined DataFrame for the specified sheets
            return df

        except Exception as e:
            print(f"Error: {str(e)}")
            traceback.print_exc()
            return None

    def get_sheet_names(self):
        try:
            sheet_metadata = self.service.spreadsheets().get(spreadsheetId=self.spreadsheet_id).execute()
            sheets = sheet_metadata.get('sheets', [])

            sheet_names = [sheet['properties']['title'] for sheet in sheets]
            return sheet_names

        except Exception as e:
            print(f"Error: {str(e)}")
            traceback.print_exc()
            return None
        
    def fetch_data(self, sheet_name):
        range_name = f'{sheet_name}!A:G'  # Adjust columns as needed
        result = self.service.spreadsheets().values().get(spreadsheetId=self.spreadsheet_id, range=range_name).execute()
        values = result.get('values', [])

        print(f'Sheet: {sheet_name}')
        if not values:
            print(f'No data found in sheet: {sheet_name}')
            return None
        month = sheet_name.split("'")[0]
        year = int(sheet_name.split("'")[1])+2000

        columns = ['Date','Money spent',
                    'Expense category', 'Spent on', 
                    'Point of Sale/App used', 'Via card/wallet/cash',
                    'Paid by']
        rows = []
        end_reached = False
        for row in values:
            if len(row) < 3:
                if end_reached:
                    break
                end_reached = True #Allow one blank space between entries
                continue
            if row[0].strip() == 'Date':
                #columns = [col.strip() for col in row]
                continue
            elif len(row) == len(columns):
                if len(row[0].strip().split(' '))>1 and len(row[0].strip().split(' '))!=3: #Minor patchwork on date
                    row[0] = f'{row[0].strip()} {year}'
                print(row)
                rows.append(row)
            elif len(row) < len(columns):
                #if row has entry for some category, only then enter it
                if len(row[2].strip())>0:
                    newrow = [col for col in row]
                    newrow += ['' for jj in range(len(row), len(columns))]
                    if len(newrow[0].strip().split(' '))>1 and len(newrow[0].strip().split(' '))!=3: #Minor patchwork on date
                        newrow[0] = f'{newrow[0].strip()} {year}'
                    print(newrow)
                    rows.append(newrow)
            else: #len > len(columns)
                rows.append(row[0:len(columns)])

        print(columns)
        df = pd.DataFrame(rows, columns=columns)

        # Clean and parse the date column
        df["Date"] = df["Date"].apply(self.clean_and_parse_date)
        #print(df.head(10))
        # Parse dates and set them as the index
        df["Date"] = pd.to_datetime(df["Date"])

        # Fill missing dates with the previous valid date
        df['Date'] = df['Date'].fillna(method='ffill')

        df.set_index("Date", inplace=True)
        print(df.head(10))
        return df

    def clean_and_parse_date(self, date_str):
        # Define regex patterns for common date formats
        date_patterns = [
            r'\d{1,2} (?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec) \d{4}',  # 27 Jan 2023
            # Add more patterns for other date formats as needed
        ]

        # Check if the date_str matches any of the patterns
        for pattern in date_patterns:
            match = re.search(pattern, date_str)
            if match:
                matched_date = match.group()
                # Perform further parsing and return a standardized date
                standardized_date = self.parse_date(matched_date)
                return standardized_date

        # If no matching pattern is found, return None (or handle as needed)
        return date_str

    def parse_date(self, date_str):
        # Implement custom logic to parse and standardize date_str
        # You can use datetime.strptime and datetime.strftime for parsing and formatting

        # Example:
        # parsed_date = datetime.datetime.strptime(date_str, "%d %b %Y")
        # standardized_date = parsed_date.strftime("%d %B %Y")
        parsed_date = datetime.strptime(date_str, "%d %b %Y")

        # Use strftime to format the date as '27 January 2023'
        standardized_date = parsed_date.strftime("%d %B %Y")
        # Return the standardized date
        return standardized_date

# %%
def run_console_hack(flow):
    flow.redirect_uri = 'http://localhost:1'
    auth_url, _ = flow.authorization_url()
    print(
        "Visit the following URL:",
        auth_url,
        "After granting permissions, you will be redirected to an error page",
        "Copy the URL of that error page (http://localhost:1/?state=...)",
        sep="\n"
    )
    redir_url = input("URL: ")
    code = parse_qs(urlparse(redir_url).query)['code'][0]
    flow.fetch_token(code=code)
    return flow.credentials

# %%
def get_credentials():
    token = 'token.json'
    creds = None
    if os.path.exists(token):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                                            'credentials.json', SCOPES)
            #creds = flow.run_local_server(port=0)
            creds = run_console_hack(flow)
        # Save the credentials for the next run
        with open(token, 'w') as tokenfile:
            tokenfile.write(creds.to_json())
    return creds

# %%
def reclassify(df):
    # Define a dictionary to map keywords to categories
    keyword_to_category = {
        'Milk': 'Groceries',
        'Curd': 'Groceries',
        'Rent': 'Household',
        'Vegetables': 'Groceries',
        'Fruits': 'Groceries',
        'Eggs': 'Groceries',
        'Flour': 'Groceries',
        'Book' : 'Books',
        # Add more keyword-category mappings as needed
    }
    # Iterate through the DataFrame and update 'Expense category' based on keywords
    for keyword, category in keyword_to_category.items():
        df.loc[df['Spent on'].str.contains(keyword, case=False, na=False), 'Expense category'] = category
    # Reclassify entries within 'Transport' category based on keywords
    transport_keywords = ['IIT', 'office', 'college', 'auto', 'uber', 'rapido', 'ola']  # Add more keywords as needed
    for keyword in transport_keywords:
        df.loc[(df['Expense category'] == 'Transport') & (df['Spent on'].str.contains(keyword, case=False, na=False)), 'Expense category'] = 'Local Transport'
    return df

# %%
offline=False
creds = None
if not offline:
    creds = get_credentials()

gsheet = Sheets(creds=creds, spreadsheet_id='<id>', offline=offline)
#sheet_names = gsheet.get_sheet_names()
sheet_names = ["September'23", "August'23", "July'23", "June'23", "May'23", "April'23",
                "March'23", "February'23", "January'23", "December'22", "September'22", 
                "August'22", "July'22", "June'22", "May'22", "April'22", "March'22", 
                "February'22", "January'22", "December'21", "November'21", "October'21", 
                "September'21", "August'21", "July'21", "Jun '21", "May'21", "April'21", 
                "March'21", "February'21", "January'21", "December'20", "November'20", 
                "October'20", "September'20", "August'20", "July'20", "June'20", "May'20", 
                "April'20", "March'20", "February'20", "January'20", "December'19", 
                "November'19", "October'19", "September'19"]
#print(sheet_names)
df = gsheet.open(sheet_names=sheet_names)

# %%
df = reclassify(df)

# %%
# Group the DataFrame by 'Expense category' and calculate the sum of 'Money spent'
expense_summary = df.groupby('Expense category')['Money spent'].sum().reset_index()

# Rename the 'Money spent' column to 'Total spent'
expense_summary.rename(columns={'Money spent': 'Total spent'}, inplace=True)

# Sort the summary DataFrame by 'Total spent' in descending order
expense_summary = expense_summary.sort_values(by='Total spent', ascending=False)

# Print the summary
print(expense_summary)
# Out:
#    Expense category  Total spent
# 7          Personal   1158170.00
# 5         Household    899372.33
# 10        Transport    174596.89
# 3         Groceries    159729.93
# 4            Health    116968.00
# 0             Books     62085.00
# 1              Food     45576.11
# 11           Travel     41070.90
# 6   Local Transport     34596.58
# 8             Phone      9161.00
# 2            Fruits      3877.00
# 12             food       707.00
# 9            Snacks       300.00
# 13             misc        50.00

# %%
#Monthly summaries
# Extract the month and year from the 'Date' column
df['YearMonth'] = df.index.strftime('%Y-%m')

# Group the data by 'YearMonth' and calculate the total expenses for each month
monthly_summary = df.groupby('YearMonth')['Money spent'].sum().reset_index()

# Rename the columns for clarity
monthly_summary.columns = ['Month', 'Total Expenses']

# Display the summary
print(monthly_summary)
# Out:
#       Month  Total Expenses
# 0   2019-09       110500.15
# 1   2019-10        16809.00
# 2   2019-11        47208.00
# 3   2019-12         4506.00
# 4   2020-01        75020.00
# 5   2020-02        39553.00
# 6   2020-03        53732.46
# 7   2020-04        25113.00
# 8   2020-05        48662.00
# 9   2020-06        47047.00
# 10  2020-07        39417.00
# 11  2020-08        48621.00
# 12  2020-09        25564.00
# 13  2020-10        53538.00
# 14  2020-11        21709.00
# 15  2020-12        36529.00
# 16  2021-01       100621.00
# 17  2021-02        72778.00
# 18  2021-03        24342.00
# 19  2021-04        34875.00
# 20  2021-05        26861.00
# 21  2021-06        21242.00
# 22  2021-07        27474.00
# 23  2021-08        45326.00
# 24  2021-09        69436.00
# 25  2021-10        65786.00
# 26  2021-11         9017.00
# 27  2021-12          202.00
# 28  2022-01        76126.00
# 29  2022-02        47539.00
# 30  2022-03       228263.00
# 31  2022-04        22702.00
# 32  2022-05        22533.00
# 33  2022-06        28587.00
# 34  2022-07        35334.00
# 35  2022-08        48352.00
# 36  2022-09        37909.00
# 37  2022-12        48479.63
# 38  2023-01        99545.00
# 39  2023-02       148604.45
# 40  2023-03       285639.35
# 41  2023-04       140397.08
# 42  2023-05        27129.00
# 43  2023-06        66766.00
# 44  2023-07        76529.00
# 45  2023-08        49120.99
# 46  2023-09        23368.63
# 47  2023-11         1848.00

# %%
# Group the data by 'YearMonth' and 'Expense' and calculate the total expenses for each category each month
monthly_category_summary = df.groupby(['YearMonth', 'Expense category'])['Money spent'].sum().reset_index()

# Rename the columns for clarity
monthly_category_summary.columns = ['Month', 'Expense Category', 'Total Expenses']

# Display the summary
print(monthly_category_summary)
# Out:
#        Month Expense Category  Total Expenses
# 0    2019-09            Books         2200.00
# 1    2019-09             Food         1835.00
# 2    2019-09           Fruits           80.00
# 3    2019-09        Groceries         1825.00
# 4    2019-09           Health         4500.00
# ..       ...              ...             ...
# 289  2023-09             Food         1024.00
# 290  2023-09        Groceries         3954.63
# 291  2023-09        Household        18300.00
# 292  2023-09  Local Transport           90.00
# 293  2023-11        Household         1848.00
#
# [294 rows x 3 columns]

# %%
# Get unique months
unique_months = df['YearMonth'].unique()

# Iterate through each unique month and display the summary
for month in unique_months:
    monthly_data = df[df['YearMonth'] == month]
    monthly_category_summary = monthly_data.groupby(['Expense category'])['Money spent'].sum().reset_index()
    monthly_category_summary.columns = ['Expense Category', 'Total Expenses']
    
    print(f"Summary for {month}:")
    print(monthly_category_summary)
    print("\n")
# Out:
# Summary for 2019-09:
#   Expense Category  Total Expenses
# 0            Books         2200.00
# 1             Food         1835.00
# 2           Fruits           80.00
# 3        Groceries         1825.00
# 4           Health         4500.00
# 5        Household        15692.00
# 6  Local Transport         3532.15
# 7         Personal        80836.00
#
#
# Summary for 2019-10:
#   Expense Category  Total Expenses
# 0            Books          1795.0
# 1             Food          1202.0
# 2        Groceries          2013.0
# 3        Household          3460.0
# 4  Local Transport           774.0
# 5         Personal          6365.0
# 6        Transport          1200.0
#
#
# Summary for 2019-11:
#   Expense Category  Total Expenses
# 0             Food          1174.0
# 1        Groceries          2209.0
# 2           Health            50.0
# 3        Household          5219.0
# 4  Local Transport          1684.0
# 5         Personal         36872.0
#
#
# Summary for 2019-12:
#   Expense Category  Total Expenses
# 0             Food           410.0
# 1        Groceries          1731.0
# 2        Household          1080.0
# 3  Local Transport          1074.0
# 4         Personal           211.0
#
#
# Summary for 2020-01:
#   Expense Category  Total Expenses
# 0            Books           700.0
# 1             Food          2517.0
# 2           Fruits           106.0
# 3        Groceries          2746.0
# 4        Household         23170.0
# 5  Local Transport          3564.0
# 6         Personal         34540.0
# 7            Phone           555.0
# 8        Transport          7122.0
#
#
# Summary for 2020-02:
#   Expense Category  Total Expenses
# 0            Books          6227.0
# 1             Food          1491.0
# 2        Groceries          3333.0
# 3           Health         15665.0
# 4        Household          9017.0
# 5  Local Transport           756.0
# 6         Personal          2999.0
# 7        Transport            65.0
#
#
# Summary for 2020-03:
#   Expense Category  Total Expenses
# 0             Food          219.00
# 1        Groceries         1436.00
# 2        Household        26140.00
# 3  Local Transport          665.00
# 4         Personal        11120.00
# 5            Phone          600.00
# 6        Transport        13552.46
#
#
# Summary for 2020-04:
#   Expense Category  Total Expenses
# 0        Groceries          6442.0
# 1        Household         18671.0
#
#
# Summary for 2020-05:
#   Expense Category  Total Expenses
# 0            Books          4900.0
# 1             Food           150.0
# 2        Groceries          3592.0
# 3        Household         19856.0
# 4         Personal         20164.0
#
#
# Summary for 2020-06:
#   Expense Category  Total Expenses
# 0            Books          1661.0
# 1             Food            60.0
# 2        Groceries          6497.0
# 3        Household         33834.0
# 4         Personal          4995.0
#
#
# Summary for 2020-07:
#   Expense Category  Total Expenses
# 0             Food            60.0
# 1        Groceries          4175.0
# 2        Household         34837.0
# 3         Personal           345.0
#
#
# Summary for 2020-08:
#   Expense Category  Total Expenses
# 0             Food           360.0
# 1        Groceries          3630.0
# 2           Health           570.0
# 3        Household         25053.0
# 4         Personal         19008.0
#
#
# Summary for 2020-09:
#   Expense Category  Total Expenses
# 0             Food           464.0
# 1        Groceries          4127.0
# 2        Household         18120.0
# 3         Personal          2710.0
# 4        Transport           143.0
#
#
# Summary for 2020-10:
#   Expense Category  Total Expenses
# 0            Books           655.0
# 1        Groceries          4301.0
# 2           Health         25689.0
# 3        Household         19239.0
# 4  Local Transport           265.0
# 5         Personal          2701.0
# 6        Transport           688.0
#
#
# Summary for 2020-11:
#   Expense Category  Total Expenses
# 0             Food            50.0
# 1        Groceries          1622.0
# 2        Household         15500.0
# 3  Local Transport           314.0
# 4         Personal          4223.0
#
#
# Summary for 2020-12:
#   Expense Category  Total Expenses
# 0            Books          6199.0
# 1             Food           250.0
# 2        Groceries          3703.0
# 3        Household         18045.0
# 4         Personal          4392.0
# 5           Travel          3940.0
#
#
# Summary for 2021-01:
#   Expense Category  Total Expenses
# 0        Groceries          5755.0
# 1           Health           450.0
# 2        Household         27904.0
# 3  Local Transport          1120.0
# 4         Personal         65392.0
#
#
# Summary for 2021-02:
#   Expense Category  Total Expenses
# 0            Books           886.0
# 1        Groceries          3484.0
# 2           Health         15035.0
# 3        Household         15554.0
# 4  Local Transport           379.0
# 5         Personal         37380.0
# 6        Transport            60.0
#
#
# Summary for 2021-03:
#   Expense Category  Total Expenses
# 0        Groceries          5007.0
# 1        Household         15198.0
# 2  Local Transport           217.0
# 3         Personal          1799.0
# 4            Phone          2121.0
#
#
# Summary for 2021-04:
#   Expense Category  Total Expenses
# 0           Fruits           200.0
# 1        Groceries          6698.0
# 2           Health          1000.0
# 3        Household         21159.0
# 4  Local Transport           148.0
# 5         Personal          5670.0
#
#
# Summary for 2021-05:
#   Expense Category  Total Expenses
# 0        Groceries          2043.0
# 1        Household         17818.0
# 2        Transport          7000.0
#
#
# Summary for 2021-06:
#   Expense Category  Total Expenses
# 0        Household         14500.0
# 1         Personal          6742.0
#
#
# Summary for 2021-07:
#   Expense Category  Total Expenses
# 0             Food           974.0
# 1        Groceries          1950.0
# 2        Household         22000.0
# 3  Local Transport            50.0
# 4         Personal          2500.0
#
#
# Summary for 2021-08:
#   Expense Category  Total Expenses
# 0        Groceries          4005.0
# 1           Health          8600.0
# 2        Household         26080.0
# 3  Local Transport           947.0
# 4         Personal          5360.0
# 5        Transport           334.0
#
#
# Summary for 2021-09:
#   Expense Category  Total Expenses
# 0             Food           391.0
# 1        Groceries           839.0
# 2        Household           458.0
# 3  Local Transport           748.0
# 4         Personal         67000.0
#
#
# Summary for 2021-10:
#   Expense Category  Total Expenses
# 0            Books         14000.0
# 1             Food           789.0
# 2        Groceries          2149.0
# 3           Health           170.0
# 4        Household         17988.0
# 5  Local Transport           607.0
# 6         Personal         28602.0
# 7            Phone           419.0
# 8        Transport          1062.0
#
#
# Summary for 2021-11:
#   Expense Category  Total Expenses
# 0             Food           424.0
# 1        Groceries          2218.0
# 2        Household          3640.0
# 3         Personal          1635.0
# 4        Transport          1100.0
#
#
# Summary for 2021-12:
#   Expense Category  Total Expenses
# 0        Groceries           202.0
#
#
# Summary for 2022-01:
#   Expense Category  Total Expenses
# 0             Food          2684.0
# 1        Groceries          2602.0
# 2           Health           685.0
# 3        Household         19213.0
# 4  Local Transport           871.0
# 5         Personal         49999.0
# 6        Transport            72.0
#
#
# Summary for 2022-02:
#   Expense Category  Total Expenses
# 0            Books          3805.0
# 1             Food           553.0
# 2        Groceries          3205.0
# 3           Health         15000.0
# 4        Household         19718.0
# 5  Local Transport           913.0
# 6         Personal          2745.0
# 7        Transport          1600.0
#
#
# Summary for 2022-03:
#   Expense Category  Total Expenses
# 0             Food          1782.0
# 1        Groceries          6716.0
# 2           Health           500.0
# 3        Household         17566.0
# 4  Local Transport          1946.0
# 5         Personal        199153.0
# 6        Transport           600.0
#
#
# Summary for 2022-04:
#   Expense Category  Total Expenses
# 0            Books          2676.0
# 1             Food          1005.0
# 2        Groceries          1423.0
# 3        Household         15124.0
# 4  Local Transport           350.0
# 5         Personal          2094.0
# 6        Transport            30.0
#
#
# Summary for 2022-05:
#   Expense Category  Total Expenses
# 0             Food           600.0
# 1        Groceries          1789.0
# 2        Household         15804.0
# 3  Local Transport          1450.0
# 4         Personal          2470.0
# 5        Transport           420.0
#
#
# Summary for 2022-06:
#   Expense Category  Total Expenses
# 0            Books           150.0
# 1             Food          1310.0
# 2        Groceries          4594.0
# 3        Household          6126.0
# 4  Local Transport          2379.0
# 5         Personal         11428.0
# 6            Phone          1800.0
# 7           Snacks           300.0
# 8        Transport           500.0
#
#
# Summary for 2022-07:
#   Expense Category  Total Expenses
# 0        Groceries          1973.0
# 1           Health           637.0
# 2        Household         18794.0
# 3  Local Transport           980.0
# 4         Personal          8600.0
# 5        Transport          4350.0
#
#
# Summary for 2022-08:
#   Expense Category  Total Expenses
# 0            Books          5400.0
# 1        Groceries          1049.0
# 2           Health          6300.0
# 3        Household         17163.0
# 4  Local Transport           500.0
# 5         Personal         16440.0
# 6        Transport          1500.0
#
#
# Summary for 2022-09:
#   Expense Category  Total Expenses
# 0            Books          2200.0
# 1             Food           250.0
# 2        Groceries          1144.0
# 3        Household         15865.0
# 4  Local Transport           610.0
# 5         Personal          9030.0
# 6        Transport          8810.0
#
#
# Summary for 2022-12:
#   Expense Category  Total Expenses
# 0            Books         5834.00
# 1             Food         1754.00
# 2        Groceries         5002.00
# 3        Household        27984.63
# 4  Local Transport          380.00
# 5         Personal         5510.00
# 6        Transport         1645.00
# 7           Travel          370.00
#
#
# Summary for 2023-01:
#   Expense Category  Total Expenses
# 0             Food          3204.0
# 1        Groceries          2048.0
# 2        Household         65483.0
# 3  Local Transport          1077.0
# 4         Personal         14060.0
# 5        Transport         13673.0
#
#
# Summary for 2023-02:
#   Expense Category  Total Expenses
# 0             Food         1036.00
# 1        Groceries         4056.00
# 2           Health          123.00
# 3        Household        25958.45
# 4  Local Transport          170.00
# 5         Personal        36279.00
# 6        Transport        80225.00
# 7             food          707.00
# 8             misc           50.00
#
#
# Summary for 2023-03:
#   Expense Category  Total Expenses
# 0             Food         3154.85
# 1        Groceries         4021.00
# 2           Health          175.00
# 3        Household        25256.00
# 4  Local Transport          614.00
# 5         Personal       217350.00
# 6        Transport          818.00
# 7           Travel        34250.50
#
#
# Summary for 2023-04:
#    Expense Category  Total Expenses
# 0             Books         1554.00
# 1              Food         3427.00
# 2            Fruits          150.00
# 3         Groceries         4752.00
# 4            Health        17971.00
# 5         Household        16672.25
# 6   Local Transport          789.43
# 7          Personal        82591.00
# 8             Phone          666.00
# 9         Transport         9314.00
# 10           Travel         2510.40
#
#
# Summary for 2023-05:
#   Expense Category  Total Expenses
# 0             Food          2702.0
# 1        Groceries          4601.0
# 2        Household         19614.0
# 3  Local Transport            50.0
# 4        Transport           162.0
#
#
# Summary for 2023-06:
#   Expense Category  Total Expenses
# 0            Books          1243.0
# 1             Food          2163.0
# 2           Fruits          1150.0
# 3        Groceries          6023.0
# 4           Health           252.0
# 5        Household         26344.0
# 6  Local Transport          1366.0
# 7         Personal         16114.0
# 8        Transport         12111.0
#
#
# Summary for 2023-07:
#   Expense Category  Total Expenses
# 0             Food          3608.0
# 1           Fruits          1070.0
# 2        Groceries          5840.0
# 3        Household         30007.0
# 4  Local Transport           514.0
# 5         Personal         22246.0
# 6            Phone          3000.0
# 7        Transport         10244.0
#
#
# Summary for 2023-08:
#   Expense Category  Total Expenses
# 0             Food         2499.26
# 1           Fruits         1121.00
# 2        Groceries         7205.30
# 3           Health         3596.00
# 4        Household        27300.00
# 5  Local Transport         2703.00
# 6         Personal         8500.00
# 7        Transport        -3803.57
#
#
# Summary for 2023-09:
#   Expense Category  Total Expenses
# 0             Food         1024.00
# 1        Groceries         3954.63
# 2        Household        18300.00
# 3  Local Transport           90.00
#
#
# Summary for 2023-11:
#   Expense Category  Total Expenses
# 0        Household          1848.0

# %%
# Combine all 'Spent on' entries into a single text string
all_spent_on_text = ', '.join(df['Spent on'].dropna())

# Split the text string by commas to extract keywords
keywords = [keyword.strip() for keyword in all_spent_on_text.split(',')]

# Create a set of unique keywords
unique_keywords = set(keywords)

# Print the unique keywords
print('Unique keywords:')
print(unique_keywords)
# Out:
# Unique keywords:
# {'', 'Pistachios', 'Lauki', 'Travel', 'Chan-ni', 'Tori', 'Biscuits', 'Keventers Coffee', 'Bidet jet', '0 power glasses', 'Smoothix', 'Napa dori', 'Knife set', 'Woolen socks', 'Rent agreement stamp', 'Waffle icecream', 'Earplugs', 'Vegetable', 'Softy', "Air tickets to Panda's wedding", 'Dahi bhalla', 'Choco Lava', 'Drum for Kuhu', 'Uber to Chandni Chowk', 'Uber from Lajpat Nagar', 'Burfi @Agarwal sweets', 'Gajar Halwa for Saurav and others', 'Adigas', 'Crocin', 'To Nandankanan Zoo', 'Make a sequence card game', 'Dinner at QDs', 'Inalsa gas stove', 'Advance to cook', 'Bathroom repairs', 'Cupcakes', 'Caretaker salary', 'Recharge Jio', 'eat out at IITD CCD', 'Hand wash', 'Auto to Lajpat Market', 'Moisturizer', 'Air Cooler', 'Amul coffee mocha drink', 'Prasaad at Taradevi', 'Advance to Cook (Sunita)', 'Garbage collector', 'Tohu Mash', 'Metro Recharge', 'Medical checks', 'Badam', 'From Paras Irene to HUDA', 'Plums', 'Pakoras', 'Dosa', 'Air Purifier', 'Millet Smoothix', 'T-Connectors', 'Auto from Saket', 'Cab to Panipat', 'Jhumke', 'Eat out', 'Trovel', 'Hair band', 'Chowmein', 'Garlic paste', 'Vegetables and Fruits', 'Jeera', 'Qutub Tickets', 'Eat out at QDs', 'Garden Shears', 'Auto back to Home from AeroCity metro', 'Gym membership', 'Bolts', 'coconut power', 'Uber (From Noida to Nehru Place)', 'Uber to College', 'Chaat at Lajpat', 'Vests and Briefs', 'Carnatic Cafe', 'Electrician', 'RO Repair and service', 'Vit C and Vit B12 capsules', 'sweets', 'Sugarfree drinks', 'RD Monthly', 'Milk and Curd', 'BIG Basket groceries', 'Dinner - Rajma Parantha', 'To Manipal', 'Rickshaws', 'Internet installation and bill for 3 months', 'Chocos', 'Lube', "Wadood's Marriage Gift contri", 'Pestle Mortar', 'Vegetable korma', 'Chair', 'Waffle cone', 'Apple Cider Vinegar', 'Kurkure Momo', 'Tomoatoes', 'To Shimla', 'Gift', 'Uber auto', 'Ginger', 'Air Pump', 'Head loop masks', 'Suit', 'Perlite', 'Flour', 'Toffee', 'Water and other charges', 'Icecream', 'Muffin', 'Harpic', 'Cone icecream', 'RT-PCR', 'Trousers', 'Cheese spread', 'Temple Oil', 'Cab in Kota', 'Books on Technical Analysis', 'Contri with Neeraj', 'Sweets for Office', 'Blinkit order', 'Cylinder', 'Lunch (Biryani)', 'Dinner: Thali', 'Thermal Inners', 'Cheese', 'To and from Dentist', 'Quilt', 'Angle bracket for cistern', 'Uber: To Airport', 'AC filter', 'ice cream', 'Tanishq scheme', 'Mseal', 'PM 2.5 sensor', 'Glass cleaner', "Ghevar to Naniji's place", 'Notebook', 'lights', 'IITD Fees', 'Coriander', 'Plumber', 'Tomato', 'Rajai Pinjayi', 'Cab From Airport', 'To and From Dentists', 'Fridge top cover', 'Cancellation charges', 'Water', 'Tissue Paper', 'AC stablizer', 'Mask', 'Compost soil', 'Biscuiits', 'Moong halwa', 'Paneer Shawarma', 'Icecream tub', 'Ma Papa gift massager', 'grocery', 'Grocery', 'Entry ticket @Konark', 'Green Tea', 'Breakfast: Upma and Chai', 'Papri', 'Blazer', 'Filters', 'Malai Kofta', 'Kent RO repair and service', 'Flights to Shimla', 'Uber to Sunder Nursery', 'Lunch @Health Pan', "Ruchi's mithayi", 'Uber Pool', 'Spectacles', 'To and From Hospital', 'Masks', 'drycleaning', 'Steel Container', 'Kaju', 'Coke', 'AC /Fridge transport', 'Geyser', 'Water bottles', 'Salad@Salad Days', 'transparent curtain', 'Garbage Bags', 'Volvo to Shimla', 'Perfumes', 'Mushroom', 'Palak Paneer', 'Meeting Neeraj', '3 Pin plug', 'on a SUnday', 'Water container for AC', 'Softener', 'Light Block Curtain', 'Urine sample box', 'Card for Aakriti', 'candles', 'AC bird protection', 'Coffee', 'Cookies', 'Sandpaper', 'Hangers', 'Tailor', 'Meetha Paan', 'Uber to Home from Airport', 'From Railway station', 'Bottle', 'Bigbasket order: Vegetables', 'paneer', 'Drain unclog', 'Metro', 'Dimsums in Shimla', 'Uber bike rides', 'Order in Swiggy', 'Dessert', 'Socks', 'DTDC courier to Milk Bag project', 'Saw', 'To Gurugram', 'Sugarfree Syrup', 'Muffler', 'Cold Coffee', 'Chamcham', 'Trading book for Papa', 'Heating pad', 'Uber to and from Noida', 'Coffee@CCD', 'Onion', 'Chocolate', 'Aloo Tikki', 'Coffee at Railway station', 'D ...

# %%
# Filter the DataFrame for 'Personal' expenses
personal_expenses = df[df['Expense category'] == 'Personal']

# Sort the 'Personal' expenses by 'Money spent' in descending order
personal_expenses_sorted = personal_expenses.sort_values(by='Money spent', ascending=False)

# Display the sorted 'Personal' expenses
print(personal_expenses_sorted)
# Out:
#            Expense category  Money spent Paid by  \
# Date
# 2023-03-25         Personal     107500.0  Anshul
# 2023-03-25         Personal     100000.0  Anshul
# 2021-09-05         Personal      67000.0     NaN
# 2021-01-11         Personal      63000.0     NaN
# 2022-03-20         Personal      62840.0     NaN
# ...                     ...          ...     ...
# 2020-05-06         Personal          5.0     NaN
# 2020-07-20         Personal          5.0     NaN
# 2020-06-28         Personal          5.0     NaN
# 2020-05-03         Personal          5.0     NaN
# 2020-05-11         Personal          4.0     NaN
#
#                                        Point of Sale/App used  \
# Date
# 2023-03-25                                            Tanishq
# 2023-03-25                                            Tanishq
# 2021-09-05                                          @Flipkart
# 2021-01-11  Lost to a con man while trying to sell my matt...
# 2022-03-20                                                NaN
# ...                                                       ...
# 2020-05-06                                                NaN
# 2020-07-20                                                NaN
# 2020-06-28                                                NaN
# 2020-05-03                                                NaN
# 2020-05-11                                                NaN
#
#                                    Spent on Via card/wallet/cash YearMonth
# Date
# 2023-03-25  Bangles (Golden Harvest Scheme)                 Cash   2023-03
# 2023-03-25                          Bangles                 Card   2023-03
# 2021-09-05                            Latop                 Card   2021-09
# 2021-01-11                            Fraud             Phone Pe   2021-01
# 2022-03-20                      Neeraj Ring                 Card   2022-03
# ...                                     ...                  ...       ...
# 2020-05-06                             Perk                 Cash   2020-05
# 2020-07-20                        Chocolate                 Cash   2020-07
# 2020-06-28                        Chocolate                 Cash   2020-06
# 2020-05-03                             Perk                 Cash   2020-05
# 2020-05-11                             Perk                 Cash   2020-05
#
# [305 rows x 7 columns]
